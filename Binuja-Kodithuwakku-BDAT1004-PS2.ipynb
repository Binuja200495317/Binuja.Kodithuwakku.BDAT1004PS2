# %% [markdown]
# # Question 1
# Consider the following Python module:
# a = 0
# def b():
# global a
# a = c(a)
# def c(a):
# return a + 2
# After importing the module into the interpreter, you execute:
# >>> b()
# >>> b()
# >>> b()
# >>> a
# ?
# What value is displayed when the last expression (a) is evaluated? Explain your
# answer by indicating what happens in every executed statement.

# %%
a=0
def b():
    global a
    a=c(a)
def c(a):
    return a+2
b()
b()
b()
a
# Out:
# 6

# %% [markdown]
# First, by calling the function 'b()', the variable 'a' is introduced as a global variable. Therefore, first the value of 'a' is taken as 0. It then equates the value of 'a' to the function 'c()' and passes the variable 'a' as the parameter of that function. Then in the function 'c()' the value of 'a' is increased by 2. In this way, calling the 'b()' function three times will increase the value of 'a' by two to three times. Then the value of 'a' will change to 6.

# %% [markdown]
# # Question 2
# Function fileLength(), given to you, takes the name of a file as input and returns
# the length of the file:
# >>> fileLength('midterm.py')
# 284
# >>> fileLength('idterm.py')
# Traceback (most recent call last):
# File "<pyshell#34>", line 1, in <module>
# fileLength('idterm.py')
# File "/Users/me/midterm.py", line 3, in fileLength
# infile = open(filename)
# FileNotFoundError: [Errno 2] No such file or directory:
# 'idterm.py'
# As shown above, if the file cannot be found by the interpreter or if it cannot be read
# as a text file, an exception will be raised. Modify function fileLength() so that a
# friendly message is printed instead:
# >>> fileLength('midterm.py')
# 358
# >>> fileLength('idterm.py')
# File idterm.py not found.

# %%
def fileLength(file_name):
    try:
        with open(file_name,'r') as f:
            print(len(f.read()))
    except FileNotFoundError:
        print('File '+file_name+' not found');

fileLength('Filelength .txt')
# Out:
# 123

# %%
fileLength('Filelength1.txt')
# Out:
# File Filelength1.txt not found

# %% [markdown]
# # Question 3
# Write a class named Marsupial that can be used as shown below:
# >>> m = Marsupial()
# >>> m.put_in_pouch('doll')
# >>> m.put_in_pouch('firetruck')
# >>> m.put_in_pouch('kitten')
# >>> m.pouch_contents()
# ['doll', 'firetruck', 'kitten']

# %%
class Marsupial:
    pouch_list = []
    def put_in_pouch(self,name):
        self.pouch_list.append(name)
        
    def pouch_contents(self):
        print(self.pouch_list)
m = Marsupial()
m.put_in_pouch('doll')
m.put_in_pouch('firetruck')
m.put_in_pouch('kitten')
m.pouch_contents()
# Out:
# ['doll', 'firetruck', 'kitten']

# %% [markdown]
# Now write a class named Kangaroo as a subclass of Marsupial that inherits all the
# attributes of Marsupial and also:
# a. extends the Marsupial __init__ constructor to take, as input, the
# coordinates x and y of the Kangaroo object,
# b. supports method jump that takes number values dx and dy as input and
# moves the kangaroo by dx units along the x-axis and by dy units along the y-
# axis, and
# c. overloads the __str__ operator so it behaves as shown below.
# >>> k = Kangaroo(0,0)
# >>> print(k)
# I am a Kangaroo located at coordinates (0,0)
# >>> k.put_in_pouch('doll')
# >>> k.put_in_pouch('firetruck')
# >>> k.put_in_pouch('kitten')
# >>> k.pouch_contents()
# ['doll', 'firetruck', 'kitten']
# >>> k.jump(1,0)
# >>> k.jump(1,0)
# >>> k.jump(1,0)
# >>> print(k)
# I am a Kangaroo located at coordinates (3,0)

# %%
class Marsupial:
    
    def __init__(self,x,y):
        self.dx=x
        self.dy=y
    pouch_list=[]
    def put_in_pouch(self,name):
        self.pouch_list.append(name)
        
    def pouch_contents(self):
        print(self.pouch_list)

class Kangaroo(Marsupial):
    
    def __init__(self,x,y):
        Marsupial.__init__(self,x,y)
        
    def jump(self,x,y):
        self.dx=self.dx+x
        self.dy=self.dy+y
        
        
    def __str__(self):
        return "I am a Kangaroo located at coordinates ("+str(self.dx)+","+str(self.dy)+")"
    
k = Kangaroo(0,0)
print(k)
k.put_in_pouch('doll')
k.put_in_pouch('firetruck')
k.put_in_pouch('kitten')
k.pouch_contents()
k.jump(1,0)
k.jump(1,0)
k.jump(1,0)
print(k)
# Out:
# I am a Kangaroo located at coordinates (0,0)
# ['doll', 'firetruck', 'kitten']
# I am a Kangaroo located at coordinates (3,0)

# %% [markdown]
# # Question 4
# Write function collatz() that takes a positive integer x as input and prints the
# Collatz sequence starting at x. A Collatz sequence is obtained by repeatedly applying
# this rule to the previous number x in the sequence:
# x = { 𝑥/2 𝑖𝑓 𝑥 𝑖𝑠 𝑒𝑣𝑒𝑛
# 3𝑥 + 1 𝑖𝑓 𝑥 𝑖𝑠 𝑜𝑑𝑑
# Your function should stop when the sequence gets to number 1. Your
# implementation must be recursive, without any loops.
# >>> collatz(1)
# 1
# >>> collatz(10)
# 10
# 5
# 16
# 8
# 4
# 2
# 1

# %%
def collatz(num):
    if num%2==0:
        print(num)
        collatz(int(num/2))
    elif num==1:
        print(num)
    else:
        print(num)
        collatz(num+1)

# %%
collatz(1)
# Out:
# 1

# %%
collatz(10)
# Out:
# 10
# 5
# 6
# 3
# 4
# 2
# 1

# %% [markdown]
# # Question 5
# Write a recursive method binary() that takes a non-negative
# integer n and prints the binary representation of integer n.
# >>> binary(0)
# 0
# >>> binary(1)
# 1
# >>> binary(3)
# 11
# >>> binary(9)
# 1001

# %%
def binary(num):
    if(num>0):
        x=num%2
        num=int(num/2)
        return int(str(binary(num))+str(x))
    else:
        return 0
binary(0)
binary(3)
binary(9)
# Out:
# 1001

# %% [markdown]
# # Question 6
# Implement a class named HeadingParser that can be used to parse an HTML
# document, and retrieve and print all the headings in the document. You should
# implement your class as a subclass of HTMLParser, defined in Standard Library
# module html.parser. When fed a string containing HTML code, your class should
# print the headings, one per line and in the order in which they appear in the
# document. Each heading should be indented as follows: an h1 heading should have
# indentation 0, and h2 heading should have indentation 1, etc. Test your
# implementation using w3c.html.
# >>> infile = open('w3c.html')
# >>> content = infile.read()
# >>> infile.close()
# >>> hp = HeadingParser()
# >>> hp.feed(content)
# W3C Mission
# Principles

# %%
from html.parser import HTMLParser

class HeadingParser(HTMLParser):
    h1_tag=""
    h2_tag=""
    
    def __init__(self):
        HTMLParser.__init__(self)
        
    def handle_starttag(self,tag,attr):
        if tag=='h1':
            self.h1_tag=True
        elif tag=='h2':
            self.h2_tag=True
            
    def handle_data(self,data):
        if self.h1_tag:
            print(data)
        elif self.h2_tag:
            print(" "+data)
            
    def handle_endtag(self,tag):
        if tag=='h1':
            self.h1_tag=False
        elif tag=='h2':
            self.h2_tag=False
            
infile = open('w3c.html')
content =infile.read()
hp = HeadingParser()
hp.feed(content)
# Out:
# W3C Mission
#  Principles

# %% [markdown]
# # Question 7
# Implement recursive function webdir() that takes as input: a URL (as a string) and
# non-negative integers depth and indent. Your function should visit every web
# page reachable from the starting URL web page in depth clicks or less, and print
# each web page's URL. As shown below, indentation, specified by indent, should
# be used to indicate the depth of a URL.
# >>>
# webdir('http://reed.cs.depaul.edu/lperkovic/csc242/test1.html'
# , 2, 0)
# http://reed.cs.depaul.edu/lperkovic/csc242/test1.html
# http://reed.cs.depaul.edu/lperkovic/csc242/test2.html
# http://reed.cs.depaul.edu/lperkovic/csc242/test4.html
# http://reed.cs.depaul.edu/lperkovic/csc242/test3.html
# http://reed.cs.depaul.edu/lperkovic/csc242/test4.html

# %%
import urllib.request
from html.parser import HTMLParser

class MyParser(HTMLParser):
    def handle_starttag(self, tag, attrs):
        if tag=='a':
            for attr in attrs:
                if attr[0]=='href':
                    if attr[1][-4:]=='html':
                        if attr[1][:4]=='http':
                            webdir(attr[1],1,1)
                        elif attr[1][:5]=='test3':
                            url='http://reed.cs.depaul.edu/lperkovic/'+attr[1]
                            webdir(url,0,1)
                        else:
                            url='http://reed.cs.depaul.edu/lperkovic/'+attr[1]
                            webdir(url,0,2)

def webdir(url,depth,indent):
    if indent==0:
        print(url)
    elif indent==1:
        print(" "+url)
    elif indent==2:
        print("  "+url)
    request = urllib.request.urlopen(url)
    html=request.read().decode("utf8")
    parser =MyParser()
    parser.feed(html)
webdir('http://reed.cs.depaul.edu/lperkovic/test1.html',2,0)
# Out:
# http://reed.cs.depaul.edu/lperkovic/test1.html
#  http://reed.cs.depaul.edu/lperkovic/test2.html
#   http://reed.cs.depaul.edu/lperkovic/test4.html
#  http://reed.cs.depaul.edu/lperkovic/test3.html
#   http://reed.cs.depaul.edu/lperkovic/test4.html

# %% [markdown]
# # Question 8
# Write SQL queries on the below database table that return:
# I have assumed the table name as temperature.
# a) All the temperature data
#
#
# select Temperature(c) from temperature;
#
#
# b) All the cities, but without repetition.
#
#
# select distinct City from temperature;
#
#
#
# c) All the records for India.
#
#
# select * from temperature where Country='India';
#
#
# d) All the Fall records
#
#
# select Rainfall(mm) from temperature ;
#
#
# e) The city, country, and season for which the average rainfall is between 200
# and 400 millimeters.
#
#
# select city,country,season from temperature where Rainfall between 200 and 400;
#
#
# f) The city and country for which the average Fall temperature is above 20
# degrees, in increasing temperature order.
#
#
# select city,country from temperature where temperature>20 order by temperature asc;
#
#
# g) The total annual rainfall for Cairo.
#
#
# select sum(Rainfall) as annual_rainfall from temperature where city='Cairo';
#
#
# h) The total rainfall for each season.
#
#
# select season,sum(Rainfall) as annual_rainfall from temperature group by season;

# %% [markdown]
# ![8-a.png](attachment:8-a.png)

# %% [markdown]
# ![8-b.png](attachment:8-b.png)

# %% [markdown]
# ![8-c.png](attachment:8-c.png)

# %% [markdown]
# ![8-d.png](attachment:8-d.png)

# %% [markdown]
# ![8-e.png](attachment:8-e.png)

# %% [markdown]
# ![8-f.png](attachment:8-f.png)

# %% [markdown]
# ![8-g.png](attachment:8-g.png)

# %% [markdown]
# ![8-h.png](attachment:8-h.png)

# %% [markdown]
# # Question 9
# . Suppose list words is defined as follows:
# >>> words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over',
# 'the', 'lazy', 'dog']
# Write list comprehension expressions that use list words and generate the following
# lists:

# %% [markdown]
# a) ['THE', 'QUICK', 'BROWN', 'FOX', 'JUMPS', 'OVER', 'THE',
# 'LAZY', 'DOG']

# %%
words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
words_upper=[]
for word in words:
    words_upper.append(word.upper())
print(words_upper)
# Out:
# ['THE', 'QUICK', 'BROWN', 'FOX', 'JUMPS', 'OVER', 'THE', 'LAZY', 'DOG']

# %% [markdown]
# b) ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the',
# 'lazy', 'dog']

# %%
words_lower=[]
for word in words:
    words_lower.append(word.lower())
print(words_lower)
# Out:
# ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

# %% [markdown]
# c) [3, 5, 5, 3, 5, 4, 3, 4, 3] (the list of lengths of words in list
# words).

# %%
words_length=[]
for word in words:
    words_length.append(len(word))
print(words_length)
# Out:
# [3, 5, 5, 3, 5, 4, 3, 4, 3]

# %% [markdown]
# d) [['THE', 'the', 3], ['QUICK', 'quick', 5], ['BROWN',
# 'brown', 5], ['FOX', 'fox', 3], ['JUMPS', 'jumps', 5],
# ['OVER', 'over', 4], ['THE', 'the', 3], ['LAZY', 'lazy',
# 4], ['DOG', 'dog', 3]] (the list containing a list for every word of list
# words, where each list contains the word in uppercase and lowercase and the
# length of the word.)

# %%
word_upper_lower_and_length=[]
for word in words:
    word_upper_and_length.append(word.upper())
    word_upper_and_length.append(word.lower())
    word_upper_and_length.append(len(word))
print(word_upper_and_length)
# Out:
# ['THE', 3, 'QUICK', 5, 'BROWN', 5, 'FOX', 3, 'JUMPS', 5, 'OVER', 4, 'THE', 3, 'LAZY', 4, 'DOG', 3, 'THE', 'the', 3, 'QUICK', 'quick', 5, 'BROWN', 'brown', 5, 'FOX', 'fox', 3, 'JUMPS', 'jumps', 5, 'OVER', 'over', 4, 'THE', 'the', 3, 'LAZY', 'lazy', 4, 'DOG', 'dog', 3]

# %% [markdown]
# e) ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the',
# 'lazy', 'dog'] (the list of words in list words containing 4 or more
# characters.)

# %%
words_limit=[]# Example answer provided with the question is contradicting. I selected words more than four characters.

for word in words:
    if len(word)>=4:# In the question it has mentioned that we need to take words with more than four characters
        words_limit.append(word.lower())
print(words_limit)
# Out:
# ['quick', 'brown', 'jumps', 'over', 'lazy']
